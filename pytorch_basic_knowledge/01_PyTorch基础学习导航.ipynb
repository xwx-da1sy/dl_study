# %% [markdown]
# # 01 PyTorch 基础学习导航
#
# 原来的第一节 notebook 太长，已经拆成下面 4 个小 notebook。建议按顺序学习。

# %% [markdown]
# ## 学习顺序
#
# 1. [01-01 Tensor 基础：创建、dtype 与 NumPy 互转](01-01_Tensor基础_创建_dtype与NumPy互转.ipynb)
# 2. [01-02 Tensor 形状：索引、形状变换、维度交换、拼接与广播](01-02_索引_形状变换_维度交换_拼接与广播.ipynb)
# 3. [01-03 Tensor 数学运算：dim、keepdim、max 与点积](01-03_数学运算_dim_keepdim_max与点积.ipynb)
# 4. [01-04 autograd 自动求导与最小线性回归](01-04_autograd自动求导与最小线性回归.ipynb)
#
# 第二节 Dataset/DataLoader 继续使用：
#
# - [02 数据读取：Dataset 与 DataLoader](02_数据读取_Dataset与DataLoader.ipynb)

# %% [markdown]
# ## 为什么这样拆
#
# - 第一份解决“Tensor 怎么来、是什么类型”。
# - 第二份解决“Tensor 的形状怎么变、多个 Tensor 怎么合起来”。
# - 第三份解决“Tensor 怎么算，dim 到底怎么理解”。
# - 第四份解决“PyTorch 怎么自动求导，并进入训练循环”。
#
# 这样每次复习只打开对应主题，不用在一个超长 notebook 里翻。
